# %%
# %matplotlib inline      
import matplotlib.pyplot as plt
import pandas as pd
from pandas.tools.plotting import scatter_matrix
import numpy as np
import seaborn as sns
import statistics as st
import matplotlib.pyplot as plt
import re

# %%
df = pd.read_csv('primary_results.csv')

# %%
#correct state abbreviations
count = 0
for index, row in df.state_abbreviation.iteritems():
    if (type(row)== str and len(row)<3):
        count=count+1
    else:
        print("Outlier in:",row)
        break;
print("Number of correct State Abbreviations:",count)
# Out:
# Number of correct State Abbreviations: 24611

# %%
#correct FIPS numbers
count=0
for index, row in df.fips.iteritems():
    if (type(row)== float):
        count = count+1
    else:
        print("Outlier")
        break;
print("Number of correct FIPS:",count)
# Out:
# Number of correct FIPS: 24611

# %%
#Check if any political party except Democrat and Republicans
count=0
term=0
for index, row in df.party.iteritems():
    if (row=='Republican' or row=='Democrat') :
        count=count+1
    else:
        term=term+1
print("Number Of instances of Democrats/Republicans:",count)
print("Number Of instances of any other party:",term)
# Out:
# Number Of instances of Democrats/Republicans: 24611
# Number Of instances of any other party: 0

# %%
#check that vote fraction for county is always less or equal to one
count=0
for index, row in df.fraction_votes.iteritems():
    if (type(row)== float and (row<=1)):
        count=count+1
    else:
        print(row)
        break;
print("Number of correct county vote fractions:",count)
# Out:
# Number of correct county vote fractions: 24611

# %%
#Names of smaller candidates
for index, row in df.candidate.iteritems():
    if (row!='Hillary Clinton' and row!='Bernie Sanders' and row!='Donald Trump' and row!='Uncommitted' and row!='John Kasich' and row!='Ted Cruz' and row!='Marco Rubio' and row!='Ben Carson') :
        print(row)
# Out:
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
#  Uncommitted
# Martin O'Malley
# ...

# %%
#Number of Counties who voted for each candidate
a=0
b=0
c=0
d=0
e=0
f=0
g=0
h=0
i=0
j=0
k=0
l=0
m=0
n=0
o=0
p=0
for index, row in df.candidate.iteritems():
    if(row=='Jeb Bush'):
         a=a+1
    elif(row=='Hillary Clinton'):
         b=b+1
    elif(row=='Donald Trump'):
         c=c+1
    elif(row=='Bernie Sanders'):
         d=d+1
    elif(row=='Ted Cruz'):
         e=e+1
    elif(row=='John Kasich'):
         f=f+1
    elif(row=='Marco Rubio'):
         g=g+1
    elif(row=='Ben Carson'):
         h=h+1
    elif(row=='Carly Fiorina'):
         i=i+1
    elif(row=='Rand Paul'):
         j=j+1
    elif(row=='Chris Christie'):
         k=k+1
    elif(row=='Mike Huckabee'):
         l=l+1
    elif(row=='Rick Santorum'):
         m=m+1
    elif(row=="Martin O'Malley"):
         p=p+1
    
print("Bernie Sanders:",d)
print("Carly Fiorina:",i)
print("Chris Christie:",k)
print("Donald Trump:",c)
print("Hillary Clinton:",b)
print("Jeb Bush:",a)
print("John Kasich:",f)
print("Marco Rubio:",g)
print("Martin O'Malley:",p)
print("Mike Huckabee:",l)
print("Rand Paul:",j)
print("Rick Santorum:",m)
print("Ted Cruz:",e)
v=[d,c,b]
can=['Bernie Sanders','Donald Trump','Hillary Clinton']
plt.pie(v)
plt.show()
# Out:
# Bernie Sanders: 4205
# Carly Fiorina: 109
# Chris Christie: 109
# Donald Trump: 3586
# Hillary Clinton: 4205
# Jeb Bush: 155
# John Kasich: 3586
# Marco Rubio: 2555
# Martin O'Malley: 99
# Mike Huckabee: 99
# Rand Paul: 99
# Rick Santorum: 99
# Ted Cruz: 3586

# %%
#Number of votes for Democrats and Republicans
a=0
b=0
c=0
d=0
e=0
f=0
g=0
h=0
i=0
j=0
k=0
l=0
m=0
n=0
o=0
p=0
demo=0
repub=0
temp = 0
for index, row in df.candidate.iteritems():
    if(row=='Jeb Bush'):
         a=a+df.votes.loc[temp]
    elif(row=='Hillary Clinton'):
         b=b+df.votes.loc[temp]
    elif(row=='Donald Trump'):
         c=c+df.votes.loc[temp]
    elif(row=='Bernie Sanders'):
         d=d+df.votes.loc[temp]
    elif(row=='Ted Cruz'):
         e=e+df.votes.loc[temp]
    elif(row=='John Kasich'):
         f=f+df.votes.loc[temp]
    elif(row=='Marco Rubio'):
         g=g+df.votes.loc[temp]
    elif(row=='Ben Carson'):
         h=h+df.votes.loc[temp]
    elif(row=='Carly Fiorina'):
         i=i+df.votes.loc[temp]
    elif(row=='Rand Paul'):
         j=j+df.votes.loc[temp]
    elif(row=='Chris Christie'):
         k=k+df.votes.loc[temp]
    elif(row=='Mike Huckabee'):
         l=l+df.votes.loc[temp]
    elif(row=='Rick Santorum'):
         m=m+df.votes.loc[temp]
    elif(row==' Uncommitted'):
         n=n+df.votes.loc[temp]
    elif(row==' No Preference'):
         o=o+df.votes.loc[temp]
    elif(row=="Martin O'Malley"):
         p=p+df.votes.loc[temp]
    temp=temp+1
demo=d+b+p
repub=c+h+j+a+f+g+k+i+l+e
print("Republican:",repub)
print("Democrats:",demo)
print("Uncommitted:",m)
print("No Response:",n)
df.party.value_counts().plot(kind='pie')
plt.show()
# Out:
# Republican: 29096904
# Democrats: 27652306
# Uncommitted: 1782
# No Response: 43

# %%
#Number of votes per candidate
a=0
b=0
c=0
d=0
e=0
f=0
g=0
h=0
i=0
j=0
k=0
l=0
m=0
n=0
o=0
p=0
temp = 0
for index, row in df.candidate.iteritems():
    if(row=='Jeb Bush'):
         a=a+df.votes.loc[temp]
    elif(row=='Hillary Clinton'):
         b=b+df.votes.loc[temp]
    elif(row=='Donald Trump'):
         c=c+df.votes.loc[temp]
    elif(row=='Bernie Sanders'):
         d=d+df.votes.loc[temp]
    elif(row=='Ted Cruz'):
         e=e+df.votes.loc[temp]
    elif(row=='John Kasich'):
         f=f+df.votes.loc[temp]
    elif(row=='Marco Rubio'):
         g=g+df.votes.loc[temp]
    elif(row=='Ben Carson'):
         h=h+df.votes.loc[temp]
    elif(row=='Carly Fiorina'):
         i=i+df.votes.loc[temp]
    elif(row=='Rand Paul'):
         j=j+df.votes.loc[temp]
    elif(row=='Chris Christie'):
         k=k+df.votes.loc[temp]
    elif(row=='Mike Huckabee'):
         l=l+df.votes.loc[temp]
    elif(row=='Rick Santorum'):
         m=m+df.votes.loc[temp]
    elif(row==' Uncommitted'):
         n=n+df.votes.loc[temp]
    elif(row==' No Preference'):
         o=o+df.votes.loc[temp]
    elif(row=="Martin O'Malley"):
         p=p+df.votes.loc[temp]
    temp=temp+1

print("Bernie Sanders:",d)
print("Carly Fiorina:",i)
print("Chris Christie:",j)
print("Donald Trump:",c)
print("Hillary Clinton:",b)
print("Jeb Bush:",a)
print("John Kasich:",f)
print("Marco Rubio:",g)
print("Martin O'Malley:",p)
print("Mike Huckabee:",l)
print("Rand Paul:",j)
print("Rick Santorum:",m)
print("Ted Cruz:",e)
print("Uncommitted:",n)
print("No Response:",o)
v=[d,b,c,e,f,g]
can=['Bernie','Hillary','Donald','Ted','John','Marco']
plt.bar(can,v)
plt.show()
# Out:
# Bernie Sanders: 11959102
# Carly Fiorina: 15191
# Chris Christie: 8479
# Donald Trump: 13302541
# Hillary Clinton: 15692452
# Jeb Bush: 94411
# John Kasich: 4159949
# Marco Rubio: 3321076
# Martin O'Malley: 752
# Mike Huckabee: 3345
# Rand Paul: 8479
# Rick Santorum: 1782
# Ted Cruz: 7603006
# Uncommitted: 43
# No Response: 8152

# %%
a=0
b=0
c=0
temp=0
for index, row in df.candidate.iteritems():
    if(row=='Bernie Sanders'):
         a=a+df.votes.loc[temp]
    elif(row=='Hillary Clinton'):
         b=b+df.votes.loc[temp]
    elif(row=='Donald Trump'):
         c=c+df.votes.loc[temp]
    temp=temp+1

print('Top 3 candidates:')
print('Bernie Sanders :',a)
print('Hillary Clinton:',b)
print('Donald Trump   :',c)
v=[a,b,c]
can=['Bernie Sanders','Hillary Clinton','Donald Trump']
plt.bar(can,v)
plt.show()
# Out:
# Top 3 candidates:
# Bernie Sanders : 11959102
# Hillary Clinton: 15692452
# Donald Trump   : 13302541

# %%
a=0
b=0
temp=0
for index, row in df.candidate.iteritems():
    if(row=='Rick Santorum'):
         a=a+df.votes.loc[temp]
    elif(row=="Martin O'Malley"):
         b=b+df.votes.loc[temp]
    temp=temp+1

print('Bottom candidates:')
print('Rick Santorum :',a)
print("Martin O'Malley:",b)
v=[a,b]
can=['Rick Santorum',"Martin O'Malley"]
plt.bar(can,v)
plt.show()
# Out:
# Bottom candidates:
# Rick Santorum : 1782
# Martin O'Malley: 752

# %%
#Greatest Number of Voters
temp=0
arr = []
a1=0
a2=0
a3=0
a4=0
a5=0
b1=0
b2=0
b3=0
b4=0
b5=0
c1=0
c2=0
c3=0
c4=0
c5=0
d1=0
d2=0
d3=0
d4=0
d5=0
e1=0
e2=0
e3=0
e4=0
e5=0
f1=0
f2=0
f3=0
f4=0
f5=0
g1=0
g2=0
g3=0
g4=0
g5=0
h1=0
h2=0
h3=0
h4=0
h5=0
i1=0
i2=0
i3=0
i4=0
i5=0
j1=0
j2=0
j3=0
j4=0
for index, row in df.state_abbreviation.iteritems():
    if(row=='AL'):
        a1=a1 + df.votes.loc[temp]
    elif(row=='AK'):
        a2=a2 + df.votes.loc[temp]
    elif(row=='AZ'):
        a3=a3 + df.votes.loc[temp]
    elif(row=='AR'):
        a4=a4 + df.votes.loc[temp]
    elif(row=='CA'):
        a5=a5 + df.votes.loc[temp]
    elif(row=='CO'):
        b1=b1 + df.votes.loc[temp]
    elif(row=='CT'):
        b2=b2 + df.votes.loc[temp]
    elif(row=='DE'):
        b3=b3 + df.votes.loc[temp]
    elif(row=='FL'):
        b4=b4 + df.votes.loc[temp]
    elif(row=='GA'):
        b5=b5 + df.votes.loc[temp]
    elif(row=='HI'):
        c1=c1 + df.votes.loc[temp]
    elif(row=='ID'):
        c2=c2 + df.votes.loc[temp]
    elif(row=='IL'):
        c3=c3 + df.votes.loc[temp]
    elif(row=='IN'):
        c4=c4 + df.votes.loc[temp]
    elif(row=='IA'):
        c5=c5 + df.votes.loc[temp]
    elif(row=='KS'):
        d1=d1 + df.votes.loc[temp]
    elif(row=='KY'):
        d2=d2 + df.votes.loc[temp]
    elif(row=='LA'):
        d3=d3 + df.votes.loc[temp]
    elif(row=='ME'):
        d4=d4 + df.votes.loc[temp]
    elif(row=='MD'):
        d5=d5 + df.votes.loc[temp]
    elif(row=='MA'):
        e1=e1 + df.votes.loc[temp]
    elif(row=='MI'):
        e2=e2 + df.votes.loc[temp]
    elif(row=='MS'):
        e3=e3 + df.votes.loc[temp]
    elif(row=='MO'):
        e4=e4 + df.votes.loc[temp]
    elif(row=='MT'):
        e5=e5 + df.votes.loc[temp]
    elif(row=='NE'):
        f1=f1 + df.votes.loc[temp]
    elif(row=='NV'):
        f2=f2 + df.votes.loc[temp]
    elif(row=='NH'):
        f3=f3 + df.votes.loc[temp]
    elif(row=='NJ'):
        f4=f4 + df.votes.loc[temp]
    elif(row=='NM'):
        f5=f5 + df.votes.loc[temp]
    elif(row=='NY'):
        g1=g1 + df.votes.loc[temp]
    elif(row=='NC'):
        g2=g2 + df.votes.loc[temp]
    elif(row=='ND'):
        g3=g3 + df.votes.loc[temp]
    elif(row=='OH'):
        g4=g4 + df.votes.loc[temp]
    elif(row=='OK'):
        g5=g5 + df.votes.loc[temp]
    elif(row=='OR'):
        h1=h1 + df.votes.loc[temp]
    elif(row=='PA'):
        h2=h2 + df.votes.loc[temp]
    elif(row=='RI'):
        h3=h3 + df.votes.loc[temp]
    elif(row=='SC'):
        h4=h4 + df.votes.loc[temp]
    elif(row=='SD'):
        h5=h5 + df.votes.loc[temp]
    elif(row=='TN'):
        i1=i1 + df.votes.loc[temp]
    elif(row=='TX'):
        i2=i2 + df.votes.loc[temp]
    elif(row=='UT'):
        i3=i3 + df.votes.loc[temp]
    elif(row=='VT'):
        i4=i4 + df.votes.loc[temp]
    elif(row=='VA'):
        i5=i5 + df.votes.loc[temp]
    elif(row=='WA'):
        j1=j1 + df.votes.loc[temp]
    elif(row=='WV'):
        j2=j2 + df.votes.loc[temp]
    elif(row=='WI'):
        j3=j3 + df.votes.loc[temp]
    elif(row=='WY'):
        j4=j4 + df.votes.loc[temp]
    temp=temp+1
arr.append(a1)
arr.append(a2)
arr.append(a3)
arr.append(a4)
arr.append(a5)
arr.append(b1)
arr.append(b2)
arr.append(b3)
arr.append(b4)
arr.append(b5)
arr.append(c1)
arr.append(c2)
arr.append(c3)
arr.append(c4)
arr.append(c5)
arr.append(d1)
arr.append(d2)
arr.append(d3)
arr.append(d4)
arr.append(d5)
arr.append(e1)
arr.append(e2)
arr.append(e3)
arr.append(e4)
arr.append(e5)
arr.append(f1)
arr.append(f2)
arr.append(f3)
arr.append(f4)
arr.append(f5)
arr.append(g1)
arr.append(g2)
arr.append(g3)
arr.append(g4)
arr.append(g5)
arr.append(h1)
arr.append(h2)
arr.append(h3)
arr.append(h4)
arr.append(h5)
arr.append(i1)
arr.append(i2)
arr.append(i3)
arr.append(i4)
arr.append(i5)
arr.append(j1)
arr.append(j2)
arr.append(j3)
arr.append(j4)
print(arr)
i=0
for i in range(0,49):
    if(arr[i]==4938197):
        print("Position on List:",i)
arr.sort()
print(arr)
print("Therefore California has greatest number of voters.")
# Out:
# [1223959, 22469, 834200, 605971, 4938197, 121184, 531302, 160416, 3940929, 2032941, 46886, 238989, 3372537, 1719291, 326704, 111296, 648885, 585781, 3415, 1233272, 1813320, 2431111, 614200, 1531672, 257516, 213691, 86815, 525966, 1321220, 309532, 2686539, 2185747, 354, 3204172, 766123, 933975, 3176340, 179594, 1105408, 119881, 1200576, 4147889, 254203, 192960, 1791672, 537150, 398352, 2073402, 1183]
# Position on List: 4
# [354, 1183, 3415, 22469, 46886, 86815, 111296, 119881, 121184, 160416, 179594, 192960, 213691, 238989, 254203, 257516, 309532, 326704, 398352, 525966, 531302, 537150, 585781, 605971, 614200, 648885, 766123, 834200, 933975, 1105408, 1200576, 1223959, 1233272, 1321220, 1531672, 1719291, 1791672, 1813320, 2032941, 2073402, 2185747, 2431111, 2686539, 3176340, 3204172, 3372537, 3940929, 4147889, 4938197]
# Therefore California has greatest number of voters.

# %%
#Least Number of Voters
temp=0
arr = []
a1=0
a2=0
a3=0
a4=0
a5=0
b1=0
b2=0
b3=0
b4=0
b5=0
c1=0
c2=0
c3=0
c4=0
c5=0
d1=0
d2=0
d3=0
d4=0
d5=0
e1=0
e2=0
e3=0
e4=0
e5=0
f1=0
f2=0
f3=0
f4=0
f5=0
g1=0
g2=0
g3=0
g4=0
g5=0
h1=0
h2=0
h3=0
h4=0
h5=0
i1=0
i2=0
i3=0
i4=0
i5=0
j1=0
j2=0
j3=0
j4=0
for index, row in df.state_abbreviation.iteritems():
    if(row=='AL'):
        a1=a1 + df.votes.loc[temp]
    elif(row=='AK'):
        a2=a2 + df.votes.loc[temp]
    elif(row=='AZ'):
        a3=a3 + df.votes.loc[temp]
    elif(row=='AR'):
        a4=a4 + df.votes.loc[temp]
    elif(row=='CA'):
        a5=a5 + df.votes.loc[temp]
    elif(row=='CO'):
        b1=b1 + df.votes.loc[temp]
    elif(row=='CT'):
        b2=b2 + df.votes.loc[temp]
    elif(row=='DE'):
        b3=b3 + df.votes.loc[temp]
    elif(row=='FL'):
        b4=b4 + df.votes.loc[temp]
    elif(row=='GA'):
        b5=b5 + df.votes.loc[temp]
    elif(row=='HI'):
        c1=c1 + df.votes.loc[temp]
    elif(row=='ID'):
        c2=c2 + df.votes.loc[temp]
    elif(row=='IL'):
        c3=c3 + df.votes.loc[temp]
    elif(row=='IN'):
        c4=c4 + df.votes.loc[temp]
    elif(row=='IA'):
        c5=c5 + df.votes.loc[temp]
    elif(row=='KS'):
        d1=d1 + df.votes.loc[temp]
    elif(row=='KY'):
        d2=d2 + df.votes.loc[temp]
    elif(row=='LA'):
        d3=d3 + df.votes.loc[temp]
    elif(row=='ME'):
        d4=d4 + df.votes.loc[temp]
    elif(row=='MD'):
        d5=d5 + df.votes.loc[temp]
    elif(row=='MA'):
        e1=e1 + df.votes.loc[temp]
    elif(row=='MI'):
        e2=e2 + df.votes.loc[temp]
    elif(row=='MS'):
        e3=e3 + df.votes.loc[temp]
    elif(row=='MO'):
        e4=e4 + df.votes.loc[temp]
    elif(row=='MT'):
        e5=e5 + df.votes.loc[temp]
    elif(row=='NE'):
        f1=f1 + df.votes.loc[temp]
    elif(row=='NV'):
        f2=f2 + df.votes.loc[temp]
    elif(row=='NH'):
        f3=f3 + df.votes.loc[temp]
    elif(row=='NJ'):
        f4=f4 + df.votes.loc[temp]
    elif(row=='NM'):
        f5=f5 + df.votes.loc[temp]
    elif(row=='NY'):
        g1=g1 + df.votes.loc[temp]
    elif(row=='NC'):
        g2=g2 + df.votes.loc[temp]
    elif(row=='ND'):
        g3=g3 + df.votes.loc[temp]
    elif(row=='OH'):
        g4=g4 + df.votes.loc[temp]
    elif(row=='OK'):
        g5=g5 + df.votes.loc[temp]
    elif(row=='OR'):
        h1=h1 + df.votes.loc[temp]
    elif(row=='PA'):
        h2=h2 + df.votes.loc[temp]
    elif(row=='RI'):
        h3=h3 + df.votes.loc[temp]
    elif(row=='SC'):
        h4=h4 + df.votes.loc[temp]
    elif(row=='SD'):
        h5=h5 + df.votes.loc[temp]
    elif(row=='TN'):
        i1=i1 + df.votes.loc[temp]
    elif(row=='TX'):
        i2=i2 + df.votes.loc[temp]
    elif(row=='UT'):
        i3=i3 + df.votes.loc[temp]
    elif(row=='VT'):
        i4=i4 + df.votes.loc[temp]
    elif(row=='VA'):
        i5=i5 + df.votes.loc[temp]
    elif(row=='WA'):
        j1=j1 + df.votes.loc[temp]
    elif(row=='WV'):
        j2=j2 + df.votes.loc[temp]
    elif(row=='WI'):
        j3=j3 + df.votes.loc[temp]
    elif(row=='WY'):
        j4=j4 + df.votes.loc[temp]
    temp=temp+1
arr.append(a1)
arr.append(a2)
arr.append(a3)
arr.append(a4)
arr.append(a5)
arr.append(b1)
arr.append(b2)
arr.append(b3)
arr.append(b4)
arr.append(b5)
arr.append(c1)
arr.append(c2)
arr.append(c3)
arr.append(c4)
arr.append(c5)
arr.append(d1)
arr.append(d2)
arr.append(d3)
arr.append(d4)
arr.append(d5)
arr.append(e1)
arr.append(e2)
arr.append(e3)
arr.append(e4)
arr.append(e5)
arr.append(f1)
arr.append(f2)
arr.append(f3)
arr.append(f4)
arr.append(f5)
arr.append(g1)
arr.append(g2)
arr.append(g3)
arr.append(g4)
arr.append(g5)
arr.append(h1)
arr.append(h2)
arr.append(h3)
arr.append(h4)
arr.append(h5)
arr.append(i1)
arr.append(i2)
arr.append(i3)
arr.append(i4)
arr.append(i5)
arr.append(j1)
arr.append(j2)
arr.append(j3)
arr.append(j4)
print(arr)
i=0
for i in range(0,49):
    if(arr[i]==354):
        print("Position on List:",i)
arr.sort()
print(arr)
print("Therefore North Dakota has least number of voters.")
# Out:
# [1223959, 22469, 834200, 605971, 4938197, 121184, 531302, 160416, 3940929, 2032941, 46886, 238989, 3372537, 1719291, 326704, 111296, 648885, 585781, 3415, 1233272, 1813320, 2431111, 614200, 1531672, 257516, 213691, 86815, 525966, 1321220, 309532, 2686539, 2185747, 354, 3204172, 766123, 933975, 3176340, 179594, 1105408, 119881, 1200576, 4147889, 254203, 192960, 1791672, 537150, 398352, 2073402, 1183]
# Position on List: 32
# [354, 1183, 3415, 22469, 46886, 86815, 111296, 119881, 121184, 160416, 179594, 192960, 213691, 238989, 254203, 257516, 309532, 326704, 398352, 525966, 531302, 537150, 585781, 605971, 614200, 648885, 766123, 834200, 933975, 1105408, 1200576, 1223959, 1233272, 1321220, 1531672, 1719291, 1791672, 1813320, 2032941, 2073402, 2185747, 2431111, 2686539, 3176340, 3204172, 3372537, 3940929, 4147889, 4938197]
# Therefore North Dakota has least number of voters.

# %%
#Distribution of Bernie, Hillary and Trump supporters in California
a=0
b=0
c=0
temp = 0
for index, row in df.candidate.iteritems():
    if(df.state.loc[temp]=="California"):
        if(row=='Donald Trump'):
            a=a + df.votes.loc[temp]
        elif(row=='Hillary Clinton'):
            b=b + df.votes.loc[temp]
        elif(row=='Bernie Sanders'):
            c=c + df.votes.loc[temp]
    temp=temp+1
print("Bernie Sanders votes in California: ",c)
print("Hillary Clinton votes in California:",b)
print("Donald Trump votes in California:   ",a)
v=[c,b,a]
can=['Bernie Sanders','Hillary Clinton','Donald Trump']
plt.bar(can,v)
plt.show()
# Out:
# Bernie Sanders votes in California:  1502043
# Hillary Clinton votes in California: 1940580
# Donald Trump votes in California:    1174829

# %%
#Distribution of Bernie, Hillary and Trump supporters in North Dakota
a=0
b=0
c=0
temp = 0
for index, row in df.candidate.iteritems():
    if(df.state.loc[temp]=="North Dakota"):
        if(row=='Donald Trump'):
            a=a + df.votes.loc[temp]
        elif(row=='Hillary Clinton'):
            b=b + df.votes.loc[temp]
        elif(row=='Bernie Sanders'):
            c=c + df.votes.loc[temp]
    temp=temp+1
print("Bernie Sanders votes in North Dakota : ",c)
print("Hillary Clinton votes in North Dakota:",b)
print("Donald Trump votes in North Dakota   :",a)
v=[c,b,a]
can=['Bernie Sanders','Hillary Clinton','Donald Trump']
plt.bar(can,v)
plt.show()
# Out:
# Bernie Sanders votes in North Dakota :  253
# Hillary Clinton votes in North Dakota: 101
# Donald Trump votes in North Dakota   : 0

# %%
#Most Republican State
a1=0
a2=0
a3=0
a4=0
a5=0
b1=0
b2=0
b3=0
b4=0
b5=0
c1=0
c2=0
c3=0
c4=0
c5=0
d1=0
d2=0
d3=0
d4=0
d5=0
e1=0
e2=0
e3=0
e4=0
e5=0
f1=0
f2=0
f3=0
f4=0
f5=0
g1=0
g2=0
g3=0
g4=0
g5=0
h1=0
h2=0
h3=0
h4=0
h5=0
i1=0
i2=0
i3=0
i4=0
i5=0
j1=0
j2=0
j3=0
j4=0
l1=0
l2=0
l3=0
l4=0
l5=0
m1=0
m2=0
m3=0
m4=0
m5=0
n1=0
n2=0
n3=0
n4=0
n5=0
o1=0
o2=0
o3=0
o4=0
o5=0
p1=0
p2=0
p3=0
p4=0
p5=0
q1=0
q2=0
q3=0
q4=0
q5=0
r1=0
r2=0
r3=0
r4=0
r5=0
s1=0
s2=0
s3=0
s4=0
s5=0
t1=0
t2=0
t3=0
t4=0
t5=0
u1=0
u2=0
u3=0
u4=0
arr = []
arr1 = []
temp=0
for index, row in df.state_abbreviation.iteritems():
    if(row=='AL' and df.party.loc[temp]=="Democrat"):
        a1=a1 + 1
    elif(row=='AK' and df.party.loc[temp]=="Democrat"):
        a2=a2 + 1
    elif(row=='AZ' and df.party.loc[temp]=="Democrat"):
        a3=a3 + 1
    elif(row=='AR' and df.party.loc[temp]=="Democrat"):
        a4=a4 + 1
    elif(row=='CA' and df.party.loc[temp]=="Democrat"):
        a5=a5 + 1
    elif(row=='CO' and df.party.loc[temp]=="Democrat"):
        b1=b1 + 1
    elif(row=='CT' and df.party.loc[temp]=="Democrat"):
        b2=b2 + 1
    elif(row=='DE' and df.party.loc[temp]=="Democrat"):
        b3=b3 + 1
    elif(row=='FL' and df.party.loc[temp]=="Democrat"):
        b4=b4 + 1
    elif(row=='GA' and df.party.loc[temp]=="Democrat"):
        b5=b5 + 1
    elif(row=='HI' and df.party.loc[temp]=="Democrat"):
        c1=c1 + 1
    elif(row=='ID' and df.party.loc[temp]=="Democrat"):
        c2=c2 + 1
    elif(row=='IL' and df.party.loc[temp]=="Democrat"):
        c3=c3 + 1
    elif(row=='IN' and df.party.loc[temp]=="Democrat"):
        c4=c4 + 1
    elif(row=='IA' and df.party.loc[temp]=="Democrat"):
        c5=c5 + 1
    elif(row=='KS' and df.party.loc[temp]=="Democrat"):
        d1=d1 + 1
    elif(row=='KY' and df.party.loc[temp]=="Democrat"):
        d2=d2 + 1
    elif(row=='LA' and df.party.loc[temp]=="Democrat"):
        d3=d3 + 1
    elif(row=='ME' and df.party.loc[temp]=="Democrat"):
        d4=d4 + 1
    elif(row=='MD' and df.party.loc[temp]=="Democrat"):
        d5=d5 + 1
    elif(row=='MA' and df.party.loc[temp]=="Democrat"):
        e1=e1 + 1
    elif(row=='MI' and df.party.loc[temp]=="Democrat"):
        e2=e2 + 1
    elif(row=='MS' and df.party.loc[temp]=="Democrat"):
        e3=e3 + 1
    elif(row=='MO' and df.party.loc[temp]=="Democrat"):
        e4=e4 + 1
    elif(row=='MT' and df.party.loc[temp]=="Democrat"):
        e5=e5 + 1
    elif(row=='NE' and df.party.loc[temp]=="Democrat"):
        f1=f1 + 1
    elif(row=='NV' and df.party.loc[temp]=="Democrat"):
        f2=f2 + 1
    elif(row=='NH' and df.party.loc[temp]=="Democrat"):
        f3=f3 + 1
    elif(row=='NJ' and df.party.loc[temp]=="Democrat"):
        f4=f4 + 1
    elif(row=='NM' and df.party.loc[temp]=="Democrat"):
        f5=f5 + 1
    elif(row=='NY' and df.party.loc[temp]=="Democrat"):
        g1=g1 + 1
    elif(row=='NC' and df.party.loc[temp]=="Democrat"):
        g2=g2 + 1
    elif(row=='ND' and df.party.loc[temp]=="Democrat"):
        g3=g3 + 1
    elif(row=='OH' and df.party.loc[temp]=="Democrat"):
        g4=g4 + 1
    elif(row=='OK' and df.party.loc[temp]=="Democrat"):
        g5=g5 + 1
    elif(row=='OR' and df.party.loc[temp]=="Democrat"):
        h1=h1 + 1
    elif(row=='PA' and df.party.loc[temp]=="Democrat"):
        h2=h2 + 1
    elif(row=='RI' and df.party.loc[temp]=="Democrat"):
        h3=h3 + 1
    elif(row=='SC' and df.party.loc[temp]=="Democrat"):
        h4=h4 + 1
    elif(row=='SD' and df.party.loc[temp]=="Democrat"):
        h5=h5 + 1
    elif(row=='TN' and df.party.loc[temp]=="Democrat"):
        i1=i1 + 1
    elif(row=='TX' and df.party.loc[temp]=="Democrat"):
        i2=i2 + 1
    elif(row=='UT' and df.party.loc[temp]=="Democrat"):
        i3=i3 + 1
    elif(row=='VT' and df.party.loc[temp]=="Democrat"):
        i4=i4 + 1
    elif(row=='VA' and df.party.loc[temp]=="Democrat"):
        i5=i5 + 1
    elif(row=='WA' and df.party.loc[temp]=="Democrat"):
        j1=j1 + 1
    elif(row=='WV' and df.party.loc[temp]=="Democrat"):
        j2=j2 + 1
    elif(row=='WI' and df.party.loc[temp]=="Democrat"):
        j3=j3 + 1
    elif(row=='WY' and df.party.loc[temp]=="Democrat"):
        j4=j4 + 1
    elif(row=='AL' and df.party.loc[temp]=="Republican"):
        l1=l1 + 1
    elif(row=='AK' and df.party.loc[temp]=="Republican"):
        l2=l2 + 1
    elif(row=='AZ' and df.party.loc[temp]=="Republican"):
        l3=l3 + 1
    elif(row=='AR' and df.party.loc[temp]=="Republican"):
        l4=l4 + 1
    elif(row=='CA' and df.party.loc[temp]=="Republican"):
        l5=l5 + 1
    elif(row=='CO' and df.party.loc[temp]=="Republican"):
        m1=m1 + 1
    elif(row=='CT' and df.party.loc[temp]=="Republican"):
        m2=m2 + 1
    elif(row=='DE' and df.party.loc[temp]=="Republican"):
        m3=m3 + 1
    elif(row=='FL' and df.party.loc[temp]=="Republican"):
        m4=m4 + 1
    elif(row=='GA' and df.party.loc[temp]=="Republican"):
        m5=m5 + 1
    elif(row=='HI' and df.party.loc[temp]=="Republican"):
        n1=n1 + 1
    elif(row=='ID' and df.party.loc[temp]=="Republican"):
        n2=n2 + 1
    elif(row=='IL' and df.party.loc[temp]=="Republican"):
        n3=n3 + 1
    elif(row=='IN' and df.party.loc[temp]=="Republican"):
        n4=n4 + 1
    elif(row=='IA' and df.party.loc[temp]=="Republican"):
        n5=n5 + 1
    elif(row=='KS' and df.party.loc[temp]=="Republican"):
        o1=o1 + 1
    elif(row=='KY' and df.party.loc[temp]=="Republican"):
        o2=o2 + 1
    elif(row=='LA' and df.party.loc[temp]=="Republican"):
        o3=o3 + 1
    elif(row=='ME' and df.party.loc[temp]=="Republican"):
        o4=o4 + 1
    elif(row=='MD' and df.party.loc[temp]=="Republican"):
        o5=o5 + 1
    elif(row=='MA' and df.party.loc[temp]=="Republican"):
        p1=p1 + 1
    elif(row=='MI' and df.party.loc[temp]=="Republican"):
        p2=p2 + 1
    elif(row=='MS' and df.party.loc[temp]=="Republican"):
        p3=p3 + 1
    elif(row=='MO' and df.party.loc[temp]=="Republican"):
        p4=p4 + 1
    elif(row=='MT' and df.party.loc[temp]=="Republican"):
        p5=p5 + 1
    elif(row=='NE' and df.party.loc[temp]=="Republican"):
        q1=q1 + 1
    elif(row=='NV' and df.party.loc[temp]=="Republican"):
        q2=q2 + 1
    elif(row=='NH' and df.party.loc[temp]=="Republican"):
        q3=q3 + 1
    elif(row=='NJ' and df.party.loc[temp]=="Republican"):
        q4=q4 + 1
    elif(row=='NM' and df.party.loc[temp]=="Republican"):
        q5=q5 + 1
    elif(row=='NY' and df.party.loc[temp]=="Republican"):
        r1=r1 + 1
    elif(row=='NC' and df.party.loc[temp]=="Republican"):
        r2=r2 + 1
    elif(row=='ND' and df.party.loc[temp]=="Republican"):
        r3=r3 + 1
    elif(row=='OH' and df.party.loc[temp]=="Republican"):
        r4=r4 + 1
    elif(row=='OK' and df.party.loc[temp]=="Republican"):
        r5=r5 + 1
    elif(row=='OR' and df.party.loc[temp]=="Republican"):
        s1=s1 + 1
    elif(row=='PA' and df.party.loc[temp]=="Republican"):
        s2=s2 + 1
    elif(row=='RI' and df.party.loc[temp]=="Republican"):
        s3=s3 + 1
    elif(row=='SC' and df.party.loc[temp]=="Republican"):
        s4=s4 + 1
    elif(row=='SD' and df.party.loc[temp]=="Republican"):
        s5=s5 + 1
    elif(row=='TN' and df.party.loc[temp]=="Republican"):
        t1=t1 + 1
    elif(row=='TX' and df.party.loc[temp]=="Republican"):
        t2=t2 + 1
    elif(row=='UT' and df.party.loc[temp]=="Republican"):
        t3=t3 + 1
    elif(row=='VT' and df.party.loc[temp]=="Republican"):
        t4=t4 + 1
    elif(row=='VA' and df.party.loc[temp]=="Republican"):
        t5=t5 + 1
    elif(row=='WA' and df.party.loc[temp]=="Republican"):
        u1=u1 + 1
    elif(row=='WV' and df.party.loc[temp]=="Republican"):
        u2=u2 + 1
    elif(row=='WI' and df.party.loc[temp]=="Republican"):
        u3=u3 + 1
    elif(row=='WY' and df.party.loc[temp]=="Republican"):
        u4=u4 + 1
    
    temp=temp+1
arr.append(a1)
arr.append(a2)
arr.append(a3)
arr.append(a4)
arr.append(a5)
arr.append(b1)
arr.append(b2)
arr.append(b3)
arr.append(b4)
arr.append(b5)
arr.append(c1)
arr.append(c2)
arr.append(c3)
arr.append(c4)
arr.append(c5)
arr.append(d1)
arr.append(d2)
arr.append(d3)
arr.append(d4)
arr.append(d5)
arr.append(e1)
arr.append(e2)
arr.append(e3)
arr.append(e4)
arr.append(e5)
arr.append(f1)
arr.append(f2)
arr.append(f3)
arr.append(f4)
arr.append(f5)
arr.append(g1)
arr.append(g2)
arr.append(g3)
arr.append(g4)
arr.append(g5)
arr.append(h1)
arr.append(h2)
arr.append(h3)
arr.append(h4)
arr.append(h5)
arr.append(i1)
arr.append(i2)
arr.append(i3)
arr.append(i4)
arr.append(i5)
arr.append(j1)
arr.append(j2)
arr.append(j3)
arr.append(j4)
arr1.append(l1)
arr1.append(l2)
arr1.append(l3)
arr1.append(l4)
arr1.append(m1)
arr1.append(m2)
arr1.append(m3)
arr1.append(m4)
arr1.append(m5)
arr1.append(n1)
arr1.append(n2)
arr1.append(n3)
arr1.append(n4)
arr1.append(n5)
arr1.append(o1)
arr1.append(o2)
arr1.append(o3)
arr1.append(o4)
arr1.append(o5)
arr1.append(p1)
arr1.append(p2)
arr1.append(p3)
arr1.append(p4)
arr1.append(p5)
arr1.append(q1)
arr1.append(q2)
arr1.append(q3)
arr1.append(q4)
arr1.append(q5)
arr1.append(r1)
arr1.append(r2)
arr1.append(r3)
arr1.append(r4)
arr1.append(r5)
arr1.append(s1)
arr1.append(s2)
arr1.append(s3)
arr1.append(s4)
arr1.append(s5)
arr1.append(t1)
arr1.append(t2)
arr1.append(t3)
arr1.append(t4)
arr1.append(t5)
arr1.append(u1)
arr1.append(u2)
arr1.append(u3)
arr1.append(u4)

print(arr1)
print(arr1.index(max(arr1)))
print("Therefore Pennyslyvania has greatest number of Republican Supporters")
# Out:
# [335, 200, 45, 375, 0, 507, 9, 268, 795, 16, 176, 412, 276, 1089, 16, 480, 256, 0, 72, 1755, 332, 328, 460, 168, 279, 85, 80, 63, 99, 186, 400, 0, 352, 385, 108, 201, 123, 276, 198, 475, 1270, 87, 1230, 665, 117, 165, 216, 48]
# 19
# Therefore Pennyslyvania has greatest number of Republican Supporters

# %%
#Polls in Pennysylvania
a=0
b=0
c=0
temp = 0
for index, row in df.candidate.iteritems():
    if(df.state_abbreviation.loc[temp]=="PA"):
        if(row=='Donald Trump'):
            a=a + df.votes.loc[temp]
        elif(row=='Hillary Clinton'):
            b=b + df.votes.loc[temp]
        elif(row=='Bernie Sanders'):
            c=c + df.votes.loc[temp]
    temp=temp+1
print("Donald Trump has ",a," number of supporters in Pennysylvania")
v=[c,b,a]
can=['Bernie Sanders','Hillary Clinton','Donald Trump']
plt.scatter(can,v)
plt.show()
# Out:
# Donald Trump has  892702  number of supporters in Pennysylvania

# %%
o=0
n=0
p=0
temp=0
for index, row in df.candidate.iteritems():
    if(row==' Uncommitted'):
        n=n+df.votes.loc[temp]
    elif(row==' No Preference'):
        o=o+df.votes.loc[temp]
    else:
        p=p+df.votes.loc[temp]
    temp=temp+1
print(n+o)
print("Active Voters:",p)
print("Uncommitted  :",n)
print("No Response  :",o)
v=[n,o]
can=['Uncommitted','No Response']
plt.bar(can,v)
plt.show()
# Out:
# 8195
# Active Voters: 56750992
# Uncommitted  : 43
# No Response  : 8152
